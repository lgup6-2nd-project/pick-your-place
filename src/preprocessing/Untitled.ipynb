# %%
import pandas as pd
import os
from pyproj import Transformer

# 프로젝트 최상위 폴더 절대경로 (본인 환경에 맞게 수정)
BASE_DIR = r"C:\Users\Admin\Desktop\pick-your-place"
os.chdir(BASE_DIR)
print("현재 작업 디렉터리:", os.getcwd())

from geocoding.vworld_geocode import road_address_to_coordinates, coordinates_to_jibun_address, road_to_jibun_address
from geocoding.admin_mapper import extract_gu_and_dong, get_gu_dong_codes
# Out:
# 현재 작업 디렉터리: C:\Users\Admin\Desktop\pick-your-place

# %%
def load_store_csv(path="data/raw/store__raw.csv"):
    if not os.path.exists(path):
        raise FileNotFoundError(f"파일이 존재하지 않습니다: {path}")
    df = pd.read_csv(path, encoding="utf-8-sig")
    print(f"[로드 완료] {path} - {len(df)}건")
    return df

# %%
def process_store_data(df):
    # '영업중' 데이터 필터링
    df = df[df['DTLSTATENM'] == '정상영업']

    # 필요한 컬럼 리스트
    needed_cols = ['MGTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'BPLCNM', 'X', 'Y']

    # 존재하는 컬럼만 선택
    selected_cols = [col for col in needed_cols if col in df.columns]
    df = df[selected_cols]

    # 컬럼명 영문으로 변경
    rename_map = {
        'MGTNO': 'store_code',
        'SITEWHLADDR': 'jibun_address',
        'RDNWHLADDR': 'road_address',
        'BPLCNM': 'store_name',
        'X': 'longitude',
        'Y': 'latitude'
    }
    df = df.rename(columns={k: v for k, v in rename_map.items() if k in df.columns})
    print(f"[전처리 완료] {len(df)}건")
    return df

# %%
def tm_to_lonlat(x, y):
    try:
        transformer = Transformer.from_crs("epsg:5181", "epsg:4326", always_xy=True)
        lon, lat = transformer.transform(x, y)
        return lon, lat
    except Exception as e:
        print(f"[좌표 변환 실패] X={x}, Y={y}, 에러: {e}")
        return None, None

def convert_coords(df, x_col='longitude', y_col='latitude'):
    def safe_convert(row):
        try:
            return tm_to_lonlat(row[x_col], row[y_col])
        except Exception as e:
            print(f"[⚠️ 변환 실패] X: {row.get(x_col)}, Y: {row.get(y_col)} → {e}")
            return (None, None)

    coords = df.apply(safe_convert, axis=1)
    df['lon'], df['lat'] = zip(*coords)
    return df

# %%
def is_within_seoul(lon, lat):
    if lon is None or lat is None:
        return False
    return 126.76 <= lon <= 127.19 and 37.41 <= lat <= 37.70

# %%
def safe_jibun_address(row):
    # 1. 기존 지번주소 있으면 우선 사용
    raw_jibun = row.get('jibun_address', '')
    if isinstance(raw_jibun, str) and raw_jibun.strip():
        return raw_jibun.strip()

    # 2. 도로명주소 → 좌표 → 지번주소
    try:
        if isinstance(row.get('road_address', ''), str) and row['road_address'].strip():
            lon, lat = road_address_to_coordinates(row['road_address'])
            if is_within_seoul(lon, lat):
                addr = coordinates_to_jibun_address(lon, lat)
                if addr and '검색결과가 없습니다' not in addr:
                    return addr
    except Exception as e:
        print(f"[도로명주소→지번주소 실패] {row.get('road_address')} → {e}")

    # 3. TM좌표 → 위경도 → 지번주소
    try:
        if is_within_seoul(row.get('lon'), row.get('lat')):
            addr = coordinates_to_jibun_address(row['lon'], row['lat'])
            if addr and '검색결과가 없습니다' not in addr:
                return addr
    except Exception as e:
        print(f"[TM좌표→지번주소 실패] ({row.get('lon')}, {row.get('lat')}) → {e}")

    # 4. 도로명주소 → 지번주소 (백업용)
    try:
        addr = road_to_jibun_address(row.get('road_address', ''))
        if addr and addr.strip():
            return addr
    except Exception as e:
        print(f"[도로명주소 백업 실패] {row.get('road_address')} → {e}")

    print(f"[⚠️ 지번주소 실패] 스토어: {row.get('store_name')}, 도로명: {row.get('road_address', '')}")
    return None

# %%
def safe_extract_gu_dong(addr):
    try:
        if addr:
            return pd.Series(extract_gu_and_dong(addr))
        else:
            return pd.Series([None, None])
    except Exception as e:
        print(f"[주소 파싱 실패] {addr} → {e}")
        return pd.Series([None, None])

# %%
def safe_get_codes(row):
    try:
        return pd.Series(get_gu_dong_codes(row['gu_name_from_jibun'], row['dong_name_from_jibun']))
    except Exception as e:
        print(f"[법정→행정 매핑 실패] gu={row.get('gu_name_from_jibun')}, dong={row.get('dong_name_from_jibun')}")
        return pd.Series([None, None])

# %%
def mapping_process(df):
    df = process_store_data(df)

    # TM 좌표를 위경도로 변환
    df = convert_coords(df, x_col='longitude', y_col='latitude')

    # 지번주소 보완
    df['jibun_address'] = df.apply(safe_jibun_address, axis=1)

    # 자치구, 행정동명 추출
    df[['gu_name_from_jibun', 'dong_name_from_jibun']] = df['jibun_address'].apply(safe_extract_gu_dong)

    # 코드 매핑
    df[['gu_code', 'dong_code']] = df.apply(safe_get_codes, axis=1)

    return df

# %%
df_raw = load_store_csv()

print("원본 데이터 컬럼:", df_raw.columns.tolist())
print("DTLSTATENM unique values:", df_raw['DTLSTATENM'].unique())
print("DTLSTATENM == '영업중' 건수:", (df_raw['DTLSTATENM'] == '영업중').sum())

df_filtered = df_raw[df_raw['DTLSTATENM'] == '영업중']
print("필터링 후 컬럼 존재 여부:")
print("X 컬럼 있음?", 'X' in df_filtered.columns)
print("Y 컬럼 있음?", 'Y' in df_filtered.columns)
print("필터링 후 행 수:", len(df_filtered))
# Out:
# [로드 완료] data/raw/store__raw.csv - 1019건
# 원본 데이터 컬럼: ['OPNSFTEAMCODE', 'MGTNO', 'APVPERMYMD', 'APVCANCELYMD', 'TRDSTATEGBN', 'TRDSTATENM', 'DTLSTATEGBN', 'DTLSTATENM', 'DCBYMD', 'CLGSTDT', 'CLGENDDT', 'ROPNYMD', 'SITETEL', 'SITEAREA', 'SITEPOSTNO', 'SITEWHLADDR', 'RDNWHLADDR', 'RDNPOSTNO', 'BPLCNM', 'LASTMODTS', 'UPDATEGBN', 'UPDATEDT', 'UPTAENM', 'X', 'Y', 'JPSENM']
# DTLSTATENM unique values: ['폐업처리' '직권취소' '정상영업' '영업개시전' nan '휴업처리']
# DTLSTATENM == '영업중' 건수: 0
# 필터링 후 컬럼 존재 여부:
# X 컬럼 있음? True
# Y 컬럼 있음? True
# 필터링 후 행 수: 0

# %%
df_raw = load_store_csv()
df_processed = mapping_process(df_raw)

# 저장 경로
output_path = os.path.abspath("data/processed/store__processed.csv")
os.makedirs(os.path.dirname(output_path), exist_ok=True)
df_processed.to_csv(output_path, index=False, encoding='utf-8-sig')
print(f"저장 완료: {output_path}")

# 매핑 실패 데이터 따로 저장 (dong_code가 없는 경우)
if 'dong_code' in df_processed.columns:
    failures = df_processed[df_processed['dong_code'].isnull()]
    failures_path = os.path.abspath("data/processed/store__failed.csv")
    failures.to_csv(failures_path, index=False, encoding='utf-8-sig')
    print(f"⚠️ 매핑 실패 데이터 저장 완료: {failures_path}")
else:
    print("[WARNING] 'dong_code' 컬럼이 없어 매핑 실패 데이터 저장하지 않음.")
# Out:
# [로드 완료] data/raw/store__raw.csv - 1019건
# [전처리 완료] 704건
# 응답 내용: {"BLD_NM" : "리첸시아 용산B", "EPSG_4326_X" : "126.967987947", "EPSG_4326_Y" : "37.537981164", "JUSO" : "서울특별시 용산구 백범로 341 (원효로1가,리첸시아 용산B)"}
# 지번 응답: {"ADDR" : "서울특별시 용산구 문배동 40-31"}
# 응답 내용: {"result":"검색결과가 없습니다."}
# [주소→좌표 실패] 서울특별시 송파구 동남로 189 (가락동, 쌍용아파트)
# 지번 응답: {"ADDR" : "서울특별시 송파구 가락동 136-5"}
# 응답 내용: {"BLD_NM" : "청담 신원아침도시마인", "EPSG_4326_X" : "127.049680053", "EPSG_4326_Y" : "37.526440427", "JUSO" : "서울특별시 강남구 도산대로85길 30 (청담동,청담 신원아침도시마인)"}
# 지번 응답: {"ADDR" : "서울특별시 강남구 청담동 122-35"}
# 응답 내용: {"BLD_NM" : "논현두산위브아파트(2단지)", "EPSG_4326_X" : "127.038308184", "EPSG_4326_Y" : "37.512286346", "JUSO" : "서울특별시 강남구 언주로122길 25 (논현동,논현두산위브아파트(2단지))"}
# 지번 응답: {"ADDR" : "서울특별시 강남구 논현동 258"}
# 응답 내용: {"BLD_NM" : "브라운스톤 레전드", "EPSG_4326_X" : "127.042313197", "EPSG_4326_Y" : "37.515494243", "JUSO" : "서울특별시 강남구 선릉로 660 (삼성동,브라운스톤 레전드)"}
# 지번 응답: {"ADDR" : "서울특별시 강남구 삼성동 8-2"}
# 응답 내용: {"result":"검색결과가 없습니다."}
# [주소→좌표 실패] 서울특별시 송파구 올림픽로 435 (신천동, 파크리오아파트)
# 지번 응답: {"ADDR" : "서울특별시 송파구 신천동 15"}
# 응답 내용: {"BLD_NM" : "", "EPSG_4326_X" : "127.133063080", "EPSG_4326_Y" : "37.493706304", "JUSO" : "서울특별시 송파구 오금로46길 49 (가락동)"}
# 지번 응답: {"ADDR" : "서울특별시 송파구 가락동 197-15"}
# 응답 내용: {"BLD_NM" : "성재빌딩", "EPSG_4326_X" : "127.061408246", "EPSG_4326_Y" : "37.515019275", "JUSO" : "서울특별시 강남구 봉은사로103길 5 (삼성동)"}
# 지번 응답: {"ADDR" : "서울특별시 강남구 삼성동 107-6"}
# 응답 내용: {"BLD_NM" : "한진아파트", "EPSG_4326_X" : "127.009225477", "EPSG_4326_Y" : "37.596039344", "JUSO" : "서울특별시 성북구 성북로4길 52 (돈암동,한진아파트)"}
# 지번 응답: {"ADDR" : "서울특별시 성북구 돈암동 609-1"}
# 응답 내용: {"BLD_NM" : "", "EPSG_4326_X" : "127.011106073", "EPSG_4326_Y" : "37.570524585", "JUSO" : "서울특별시 종로구 종로44길 14 (창신동)"}
# 지번 응답: {"ADDR" : "서울특별시 종로구 창신동 437-2"}
# 응답 내용: {"result":"검색결과가 없습니다."}
# [주소→좌표 실패] 서울특별시 중구 동호로37길 20 (방산동)
# 지번 응답: {"ADDR" : "서울특별시 중구 을지로5가 271-3"}
# 응답 내용: {"BLD_NM" : "Team204", "EPSG_4326_X" : "127.013180073", "EPSG_4326_Y" : "37.567736932", "JUSO" : "서울특별시 중구 마장로 30 (신당동)"}
# 지번 응답: {"ADDR" : "서울특별시 중구 신당동 204-79"}
# 응답 내용: {"result":"검색결과가 없습니다."}
# [주소→좌표 실패] 서울특별시 중구 청계천로 260-9 (을지로6가, 통일의류종합상가)
# 지번 응답: {"ADDR" : "서울특별시 중구 을지로6가 23-6"}
# 응답 내용: {"BLD_NM" : "", "EPSG_4326_X" : "126.987031969", "EPSG_4326_Y" : "37.567133920", "JUSO" : "서울특별시 중구 삼일대로 363 (장교동)"}
# 지번 응답: {"ADDR" : "서울특별시 중구 장교동 1"}
# 응답 내용: {"BLD_NM" : "", "EPSG_4326_X" : "127.012802102", "EPSG_4326_Y" : "37.569187018", "JUSO" : "서울특별시 중구 마장로1길 28 (신당동)"}
# 지번 응답: {"ADDR" : "서울특별시 중구 신당동 213-67"}
# 응답 내용: {"BLD_NM" : "남산타운", "EPSG_4326_X" : "127.010534128", "EPSG_4326_Y" : "37.549484230", "JUSO" : "서울특별시 중구 다산로 32 (신당동,남산타운)"}
# 지번 응답: {"ADDR" : "서울특별시 중구 신당동 844"}
# 응답 내용: {"BLD_NM" : "남산타운", "EPSG_4326_X" : "127.010534128", "EPSG_4326_Y" : "37.549484230", "JUSO" : "서울특별시 중구 다산로 32 (신당동,남산타운)"}
# 지번 응답: {"ADDR" : "서울특별시 중구 신당동 844"}
# 응답 내용: {"result":"검색결과가 없습니다."}
# [주소→좌표 실패] 서울특별시 중구 장충단로 13-20 (을지로6가)
# [도로명→지번주소 변환 실패] 서울특별시 중구 장충단로 13-20 (을지로6가) → Expecting value: line 1 column 1 (char 0)
# [⚠️ 지번주소 실패] 스토어: 현대시티타워, 도로명: 서울특별시 중구 장충단로 13-20 (을지로6가)
# 응답 내용: {"BLD_NM" : "하이해리엇", "EPSG_4326_X" : "126.985365335", "EPSG_4326_Y" : "37.561267551", "JUSO" : "서울특별시 중구 퇴계로 123 (충무로2가)"}
# 지번 응답: {"ADDR" : "서울특별시 중구 충무로2가 65-9"}
# 응답 내용: {"BLD_NM" : "제1평화시장", "EPSG_4326_X" : "127.011429374", "EPSG_4326_Y" : "37.568422952", "JUSO" : "서울특별시 중구 마장로 13 (신당동)"}
# 지번 응답: {"ADDR" : "서울특별시 중구 신당동 775"}
# 응답 내용: {"BLD_NM" : "롯데백화점(본점)", "EPSG_4326_X" : "126.981731246", "EPSG_4326_Y" : "37.564728449", "JUSO" : "서울특별시 중구 남대문로 81 (소공동)"}
# 지번 응답: {"ADDR" : "서울특별시 중구 소공동 1"}
# 응답 내용: {"BLD_NM" : "남산타운", "EPSG_4326_X" : "127.010534128", "EPSG_4326_Y" : "37.549484230", "JUSO" : "서울특별시 중구 다산로 32 (신당동,남산타운)"}
# 지번 응답: {"ADDR" : "서울특별시 중구 신당동 844"}
# 응답 내용: {"BLD_NM" : "두산타워", "EPSG_4326_X" : "127.008711651", "EPSG_4326_Y" : "37.568835534", "JUSO" : "서울특별시 중구 장충단로 275 (을지로6가)"}
# 지번 응답: {"ADDR" : "서울특별시 중구 을지로6가 18-12"}
# 응답 내용: {"BLD_NM" : "", "EPSG_4326_X" : "126.979035161", "EPSG_4326_Y" : "37.560801582", "JUSO" : "서울특별시 중구 남대문로 30 (남창동)"}
# 지번 응답: {"ADDR" : "서울특별시 중구 남창동 1-2"}
# 응답 내용: {"BLD_NM" : "", "EPSG_4326_X" : "127.006942994", "EPSG_4326_Y" : "37.569277641", "JUSO" : "서울특별시 중구 장충단로13길 34 (을지로6가)"}
# 지번 응답: {"ADDR" : "서울특별시 중구 을지로6가 17-427"}
# 응답 내용: {"BLD_NM" : "누죤빌딩", "EPSG_4326_X" : "127.013005919", "EPSG_4326_Y" : "37.566907787", "JUSO" : "서울특별시 중구 을지로45길 62 (신당동)"}
# 지번 응답: {"ADDR" : "서울특별시 중구 신당동 251-8"}
# 응답 내용: {"BLD_NM" : "", "EPSG_4326_X" : "127.001905039", "EPSG_4326_Y" : "37.565062788", "JUSO" : "서울특별시 중구 을지로36길 35 (오장동)"}
# 지번 응답: {"ADDR" : "서울특별시 중구 오장동 139-12"}
# 응답 내용: {"BLD_NM" : "디자이너크럽", "EPSG_4326_X" : "127.013118490", "EPSG_4326_Y" : "37.567395712", "JUSO" : "서울특별시 중구 을지로45길 72 (신당동)"}
# 지번 응답: {"ADDR" : "서울특별시 중구 신당동 199-1"}
# 응답 내용: {"BLD_NM" : "", "EPSG_4326_X" : "126.986337849", "EPSG_4326_Y" : "37.561869411", "JUSO" : "서울특별시 중구 명동8가길 27 (충무로2가)"}
# 지번 응답: {"ADDR" : "서울특별시 중구 충무로2가 11-1"}
# 응답 내용: {"BLD_NM" : "", "EPSG_4326_X" : "127.012533313", "EPSG_4326_Y" : "37.568687783", "JUSO" : "서울특별시 중구 마장로1길 18 (신당동)"}
# 지번 응답: {"ADDR" : "서울특별시 중구 신당동 213-49"}
# 응답 내용: {"BLD_NM" : "", "EPSG_4326_X" : "126.979108474", "EPSG_4326_Y" : "37.559918250", "JUSO" : "서울특별시 중구 남대문시장8길 7 (남창동)"}
# 지번 응답: {"ADDR" : "서울특별시 중구 남창동 5"}
# 응답 내용: {"BLD_NM" : "남정빌딩", "EPSG_4326_X" : "126.976413501", "EPSG_4326_Y" : "37.558723507", "JUSO" : "서울특별시 중구 소월로 9 (남창동)"}
# 지번 응답: {"ADDR" : "서울특별시 중구 남창동 52-3"}
# 응답 내용: {"result":"검색결과가 없습니다."}
# [주소→좌표 실패] 서울특별시 중구 을지로 276 (을지로7가, apMPLACE)
# 지번 응답: {"ADDR" : "서울특별시 중구 장충동1가 38-36"}
# 응답 내용: {"BLD_NM" : "", "EPSG_4326_X" : "127.015597636", "EPSG_4326_Y" : "37.562846369", "JUSO" : "서울특별시 중구 다산로 222 (신당동)"}
# 지번 응답: {"ADDR" : "서울특별시 중구 신당동 292-43"}
# 응답 내용: {"result":"검색결과가 없습니다."}
# [주소→좌표 실패] 서울특별시 중구 마장로 22 (신당동, DDP FASHION MALL)
# 지번 응답: {"ADDR" : "서울특별시 중구 신당동 233-19"}
# 응답 내용: {"BLD_NM" : "", "EPSG_4326_X" : "127.019789294", "EPSG_4326_Y" : "37.566796684", "JUSO" : "서울특별시 중구 퇴계로85길 22 (황학동)"}
# 지번 응답: {"ADDR" : "서울특별시 중구 황학동 409"}
# 응답 내용: {"result":"검색결과가 없습니다."}
# [주소→좌표 실패] 서울특별시 중구 만리재로 175, 401동 9,10,11호 (만리동2가)
# 지번 응답: {"ADDR" : "서울특별시 용산구 서계동 267-8"}
# 응답 내용: {"BLD_NM" : "서울숲 더샵", "EPSG_4326_X" : "127.040185193", "EPSG_4326_Y" : "37.557137037", "JUSO" : "서울특별시 성동구 왕십리로 241 (행당동,서울숲 더샵)"}
# 지번 응답: {"ADDR" : "서울특별시 성동구 행당동 377"}
# 응답 내용: {"BLD_NM" : "", "EPSG_4326_X" : "127.052930341", "EPSG_4326_Y" : "37.593346082", "JUSO" : "서울특별시 동대문구 경희대로 20 (회기동)"}
# 지번 응답: {"ADDR" : "서울특별시 동대문구 회기동 33-1"}
# 응답 내용: {"BLD_NM" : "상봉 프레미어스 엠코", "EPSG_4326_X" : "127.090090871", "EPSG_4326_Y" : "37.597951233", "JUSO" : "서울특별시 중랑구 망우로 353 (상봉동,상봉 프레미어스 엠코)"}
# 지번 응답: {"ADDR" : "서울특별시 중랑구 상봉동 500"}
# 응답 내용: {"BLD_NM" : "동원시장", "EPSG_4326_X" : "127.089889271", "EPSG_4326_Y" : "37.589851313", "JUSO" : "서울특별시 중랑구 면목로74길 45 (면목동)"}
# 지번 응답: {"ADDR" : "서울특별시 중랑구 면목동 101-1"}
# 응답 내용: {"BLD_NM" : "보문파크뷰자이", "EPSG_4326_X" : "127.018503367", "EPSG_4326_Y" : "37.578037649", "JUSO" : "서울특별시 성북구 보문사길 111 (보문동6가,보문파크뷰자이)"}
# 지번 응답: {"ADDR" : "서울특별시 성북구 보문동6가 458"}
# 응답 내용: {"BLD_NM" : "성북프라자", "EPSG_4326_X" : "127.026517195", "EPSG_4326_Y" : "37.621562309", "JUSO" : "서울특별시 강북구 도봉로33길 18 (미아동,성북프라자)"}
# 지번 응답: {"ADDR" : "서울특별시 강북구 미아동 318-5"}
# 응답 내용: {"BLD_NM" : "남송빌딩", "EPSG_4326_X" : "127.027361924", "EPSG_4326_Y" : "37.624220969", "JUSO" : "서울특별시 강북구 도봉로 172 (미아동)"}
# 지번 응답: {"ADDR" : "서울특별시 강북구 미아동 126-3"}
# 응답 내용: {"BLD_NM" : "", "EPSG_4326_X" : "127.020019221", "EPSG_4326_Y" : "37.646026626", "JUSO" : "서울특별시 강북구 노해로23길 68 (수유동)"}
# 지번 응답: {"ADDR" : "서울특별시 강북구 수유동 270-185"}
# 응답 내용: {"result":"검색결과가 없습니다."}
# [주소→좌표 실패] 서울특별시 노원구 동일로180길 14 (공릉동, 공릉종합상가)
# 지번 응답: {"ADDR" : "서울특별시 노원구 공릉동 610-1"}
# 응답 내용: {"result":"검색결과가 없습니다."}
# [주소→좌표 실패] 서울특별시 서대문구 수색로2길 47 (남가좌동)
# [도로명→지번주소 변환 실패] 서울특별시 서대문구 수색로2길 47 (남가좌동) → Expecting value: line 1 column 1 (char 0)
# [⚠️ 지번주소 실패] 스토어: 서중시장, 도로명: 서울특별시 서대문구 수색로2길 47 (남가좌동)
# 응답 내용: {"BLD_NM" : "", "EPSG_4326_X" : "126.910109465", "EPSG_4326_Y" : "37.577882409", "JUSO" : "서울특별시 서대문구 응암로 54 (북가좌동)"}
# 지번 응답: {"ADDR" : "서울특별시 서대문구 북가좌동 306-17"}
# 응답 내용: {"result":"검색결과가 없습니다."}
# [주소→좌표 실패] 서울특별시 마포구 토정로 282 (용강동)
# [도로명→지번주소 변환 실패] 서울특별시 마포구 토정로 282 (용강동) → Expecting value: line 1 column 1 (char 0)
# [⚠️ 지번주소 실패] 스토어: 홈플러스익스프레스 용강점, 도로명: 서울특별시 마포구 토정로 282 (용강동)
# 응답 내용: {"BLD_NM" : "롯데캐슬 프레지던트", "EPSG_4326_X" : "126.950847496", "EPSG_4326_Y" : "37.545068654", "JUSO" : "서울특별시 마포구 마포대로 109 (공덕동,롯데캐슬 프레지던트)"}
# 지번 응답: {"ADDR" : "서울특별시 마포구 공덕동 467"}
# 응답 내용: {"BLD_NM" : "", "EPSG_4326_X" : "126.940245400", "EPSG_4326_Y" : "37.545328948", "JUSO" : "서울특별시 마포구 큰우물로 3 (대흥동)"}
# 지번 응답: {"ADDR" : "서울특별시 마포구 대흥동 337-10"}
# 응답 내용: {"result":"검색결과가 없습니다."}
# [주소→좌표 실패] 서울특별시 강서구 화곡로 274 (화곡동, 외4필지 크라운뷰 1층 104~109)
# 지번 응답: {"ADDR" : "서울특별시 강서구 화곡동 24-88"}
# 응답 내용: {"BLD_NM" : "주상복합두산아파트", "EPSG_4326_X" : "126.893633282", "EPSG_4326_Y" : "37.475433214", "JUSO" : "서울특별시 금천구 가산로 106 (가산동,주상복합두산아파트)"}
# 지번 응답: {"ADDR" : "서울특별시 금천구 가산동 772"}
# 응답 내용: {"BLD_NM" : "", "EPSG_4326_X" : "126.891552660", "EPSG_4326_Y" : "37.526068572", "JUSO" : "서울특별시 영등포구 선유로 138 (양평동3가)"}
# 지번 응답: {"ADDR" : "서울특별시 영등포구 양평동3가 45"}
# 응답 내용: {"BLD_NM" : "돈보스코청소년센터", "EPSG_4326_X" : "126.913709477", "EPSG_4326_Y" : "37.497660601", "JUSO" : "서울특별시 영등포구 여의대방로 65 (신길동)"}
# 지번 응답: {"ADDR" : "서울특별시 영등포구 신길동 4491"}
# 응답 내용: {"BLD_NM" : "여의도자이", "EPSG_4326_X" : "126.925265745", "EPSG_4326_Y" : "37.518114096", "JUSO" : "서울특별시 영등포구 여의동로3길 10 (여의도동,여의도자이)"}
# 지번 응답: {"ADDR" : "서울특별시 영등포구 여의도동 47"}
# 응답 내용: {"BLD_NM" : "", "EPSG_4326_X" : "126.911344557", "EPSG_4326_Y" : "37.483228224", "JUSO" : "서울특별시 관악구 조원로16길 27 (신림동)"}
# 지번 응답: {"ADDR" : "서울특별시 관악구 신림동 541"}
# 응답 내용: {"BLD_NM" : "", "EPSG_4326_X" : "126.920230774", "EPSG_4326_Y" : "37.470519852", "JUSO" : "서울특별시 관악구 난곡로26길 4 (신림동)"}
# 지번 응답: {"ADDR" : "서울특별시 관악구 신림동 637-1"}
# 응답 내용: {"BLD_NM" : "", "EPSG_4326_X" : "127.118788507", "EPSG_4326_Y" : "37.503510813", "JUSO" : "서울특별시 송파구 오금로32길 32 (송파동)"}
# 지번 응답: {"ADDR" : "서울특별시 송파구 송파동 163-17"}
# 응답 내용: {"BLD_NM" : "국제전자센터", "EPSG_4326_X" : "127.017826546", "EPSG_4326_Y" : "37.484756886", "JUSO" : "서울특별시 서초구 효령로 304 (서초동)"}
# 지번 응답: {"ADDR" : "서울특별시 서초구 서초동 1445-3"}
# 응답 내용: {"BLD_NM" : "반포프라자", "EPSG_4326_X" : "126.986908631", "EPSG_4326_Y" : "37.502129199", "JUSO" : "서울특별시 서초구 신반포로3길 8 (반포동)"}
# 지번 응답: {"ADDR" : "서울특별시 서초구 반포동 1313"}
# 응답 내용: {"BLD_NM" : "신동아아파트", "EPSG_4326_X" : "127.024065401", "EPSG_4326_Y" : "37.490495233", "JUSO" : "서울특별시 서초구 사임당로 130 (서초동,신동아아파트)"}
# 지번 응답: {"ADDR" : "서울특별시 서초구 서초동 1334"}
# 응답 내용: {"BLD_NM" : "", "EPSG_4326_X" : "126.983836042", "EPSG_4326_Y" : "37.481856771", "JUSO" : "서울특별시 서초구 방배천로16길 18 (방배동)"}
# 지번 응답: {"ADDR" : "서울특별시 서초구 방배동 456-1"}
# 응답 내용: {"BLD_NM" : "신반포상가", "EPSG_4326_X" : "126.994721931", "EPSG_4326_Y" : "37.505474318", "JUSO" : "서울특별시 서초구 신반포로15길 29 (반포동)"}
# 지번 응답: {"ADDR" : "서울특별시 서초구 반포동 2-8"}
# 응답 내용: {"BLD_NM" : "신반포아파트", "EPSG_4326_X" : "127.014194133", "EPSG_4326_Y" : "37.515444131", "JUSO" : "서울특별시 서초구 나루터로 37 (잠원동)"}
# 지번 응답: {"ADDR" : "서울특별시 서초구 잠원동 50-5"}
# 응답 내용: {"BLD_NM" : "서초리시온", "EPSG_4326_X" : "127.015445755", "EPSG_4326_Y" : "37.493455957", "JUSO" : "서울특별시 서초구 서초중앙로22길 25 (서초동,서초리시온)"}
# 지번 응답: {"ADDR" : "서울특별시 서초구 서초동 1671-5"}
# 응답 내용: {"BLD_NM" : "아크로비스타", "EPSG_4326_X" : "127.012895433", "EPSG_4326_Y" : "37.498406983", "JUSO" : "서울특별시 서초구 서초중앙로 188 (서초동,아크로비스타)"}
# 지번 응답: {"ADDR" : "서울특별시 서초구 서초동 1685-3"}
# 응답 내용: {"BLD_NM" : "", "EPSG_4326_X" : "127.036892786", "EPSG_4326_Y" : "37.462515128", "JUSO" : "서울특별시 서초구 매헌로 16 (양재동)"}
# 지번 응답: {"ADDR" : "서울특별시 서초구 양재동 215"}
# 응답 내용: {"BLD_NM" : "교보생명보험(주) 서초사옥", "EPSG_4326_X" : "127.024112096", "EPSG_4326_Y" : "37.503758590", "JUSO" : "서울특별시 서초구 강남대로 465 (서초동)"}
# 지번 응답: {"ADDR" : "서울특별시 서초구 서초동 1303-22"}
# 응답 내용: {"BLD_NM" : "방배한신트리플", "EPSG_4326_X" : "126.989269961", "EPSG_4326_Y" : "37.491235133", "JUSO" : "서울특별시 서초구 방배로33길 29 (방배동,방배한신트리플)"}
# 지번 응답: {"ADDR" : "서울특별시 서초구 방배동 816-1"}
# 응답 내용: {"BLD_NM" : "코스트코양재점", "EPSG_4326_X" : "127.036180760", "EPSG_4326_Y" : "37.461950318", "JUSO" : "서울특별시 서초구 양재대로 159 (양재동)"}
# 지번 응답: {"ADDR" : "서울특별시 서초구 양재동 217-6"}
# 응답 내용: {"BLD_NM" : "반포프라자", "EPSG_4326_X" : "126.986908631", "EPSG_4326_Y" : "37.502129199", "JUSO" : "서울특별시 서초구 신반포로3길 8 (반포동)"}
# 지번 응답: {"ADDR" : "서울특별시 서초구 반포동 1313"}
# 응답 내용: {"BLD_NM" : "킴스클럽", "EPSG_4326_X" : "127.006975423", "EPSG_4326_Y" : "37.510243952", "JUSO" : "서울특별시 서초구 잠원로 69 (잠원동)"}
# 지번 응답: {"ADDR" : "서울특별시 서초구 잠원동 70-1"}
# 응답 내용: {"result":"검색결과가 없습니다."}
# [주소→좌표 실패] 서울특별시 서초구 나루터로 32 (잠원동)
# [도로명→지번주소 변환 실패] 서울특별시 서초구 나루터로 32 (잠원동) → Expecting value: line 1 column 1 (char 0)
# [⚠️ 지번주소 실패] 스토어: 대림상가, 도로명: 서울특별시 서초구 나루터로 32 (잠원동)
# 응답 내용: {"result":"검색결과가 없습니다."}
# [주소→좌표 실패] 서울특별시 서초구 고무래로 90-7 (서초동)
# 지번 응답: {"ADDR" : "서울특별시 서초구 서초동 1685"}
# 응답 내용: {"BLD_NM" : "반포 래미안아이파크", "EPSG_4326_X" : "127.012560431", "EPSG_4326_Y" : "37.500898849", "JUSO" : "서울특별시 서초구 서초중앙로 220 (반포동,반포 래미안아이파크)"}
# 지번 응답: {"ADDR" : "서울특별시 서초구 반포동 1341"}
# 응답 내용: {"BLD_NM" : "", "EPSG_4326_X" : "127.059443497", "EPSG_4326_Y" : "37.509632062", "JUSO" : "서울특별시 강남구 테헤란로87길 22 (삼성동)"}
# 지번 응답: {"ADDR" : "서울특별시 강남구 삼성동 159-6"}
# 응답 내용: {"BLD_NM" : "점프밀라노", "EPSG_4326_X" : "127.026616507", "EPSG_4326_Y" : "37.501231917", "JUSO" : "서울특별시 강남구 강남대로 432 (역삼동)"}
# 지번 응답: {"ADDR" : "서울특별시 강남구 역삼동 815"}
# 응답 내용: {"result":"검색결과가 없습니다."}
# [주소→좌표 실패] 서울특별시 강남구 삼성로 633, 1층 (삼성동, 삼광빌딩)
# 지번 응답: {"ADDR" : "서울특별시 강남구 삼성동 111-130"}
# 응답 내용: {"BLD_NM" : "동화상가", "EPSG_4326_X" : "127.023598225", "EPSG_4326_Y" : "37.510383443", "JUSO" : "서울특별시 강남구 학동로4길 15 (논현동)"}
# 지번 응답: {"ADDR" : "서울특별시 강남구 논현동 122-8"}
# 응답 내용: {"BLD_NM" : "", "EPSG_4326_X" : "127.030225099", "EPSG_4326_Y" : "37.513523563", "JUSO" : "서울특별시 강남구 학동로 176 (논현동)"}
# 지번 응답: {"ADDR" : "서울특별시 강남구 논현동 129"}
# 응답 내용: {"BLD_NM" : "한국산업양행빌딩", "EPSG_4326_X" : "127.025571709", "EPSG_4326_Y" : "37.523437235", "JUSO" : "서울특별시 강남구 압구정로18길 25 (신사동)"}
# 지번 응답: {"ADDR" : "서울특별시 강남구 신사동 568-25"}
# 응답 내용: {"BLD_NM" : "", "EPSG_4326_X" : "127.093339903", "EPSG_4326_Y" : "37.512487910", "JUSO" : "서울특별시 송파구 올림픽로 203 (잠실동)"}
# 지번 응답: {"ADDR" : "서울특별시 송파구 잠실동 27-6"}
# 응답 내용: {"BLD_NM" : "", "EPSG_4326_X" : "127.116739315", "EPSG_4326_Y" : "37.506368156", "JUSO" : "서울특별시 송파구 가락로28길 7 (송파동)"}
# 지번 응답: {"ADDR" : "서울특별시 송파구 송파동 150-2"}
# 응답 내용: {"result":"검색결과가 없습니다."}
# [주소→좌표 실패] 서울특별시 송파구 오금로31가길 20 (방이동, 대림아파트)
# 지번 응답: {"ADDR" : "서울특별시 송파구 송파동 166-3"}
# [법정→행정 매핑 실패] gu=은평구, dong=불광1동
# [법정→행정 매핑 실패] gu=강동구, dong=암사3동
# [법정→행정 매핑 실패] gu=송파구, dong=잠실3동
# [법정→행정 매핑 실패] gu=성북구, dong=돈암2동
# [법정→행정 매핑 실패] gu=송파구, dong=풍납2동
# [법정→행정 매핑 실패] gu=송파구, dong=방이2동
# [법정→행정 매핑 실패] gu=송파구, dong=잠실2동
# [법정→행정 매핑 실패] gu=None, dong=None
# [법정→행정 매핑 실패] gu=None, dong=None
# [법정→행정 매핑 실패] gu=중구, dong=신당1동
# [법정→행정 매핑 실패] gu=중구, dong=신당1동
# [법정→행정 매핑 실패] gu=중구, dong=신당1동
# [법정→행정 매핑 실패] gu=중구, dong=신당1동
# [법정→행정 매핑 실패] gu=성동구, dong=왕십리2동
# [법정→행정 매핑 실패] gu=성동구, dong=왕십리도선동
# [법정→행정 매핑 실패] gu=광진구, dong=중곡1동
# [법정→행정 매핑 실패] gu=광진구, dong=중곡4동
# [법정→행정 매핑 실패] gu=광진구, dong=중곡2동
# [법정→행정 매핑 실패] gu=광진구, dong=구의2동
# [법정→행정 매핑 실패] gu=광진구, dong=구의3동
# [법정→행정 매핑 실패] gu=동대문구, dong=이문1동
# [법정→행정 매핑 실패] gu=동대문구, dong=전농1동
# [법정→행정 매핑 실패] gu=동대문구, dong=전농1동
# [법정→행정 매핑 실패] gu=동대문구, dong=답십리1동
# [법정→행정 매핑 실패] gu=중랑구, dong=신내1동
# [법정→행정 매핑 실패] gu=중랑구, dong=중화2동
# [법정→행정 매핑 실패] gu=중랑구, dong=중화2동
# [법정→행정 매핑 실패] gu=중랑구, dong=면목3.8동
# [법정→행정 매핑 실패] gu=중랑구, dong=망우3동
# [법정→행정 매핑 실패] gu=중랑구, dong=면목7동
# [법정→행정 매핑 실패] gu=중랑구, dong=신내2동
# [법정→행정 매핑 실패] gu=중랑구, dong=묵1동
# [법정→행정 매핑 실패] gu=중랑구, dong=상봉1동
# [법정→행정 매핑 실패] gu=성북구, dong=정릉3동
# [법정→행정 매핑 실패] gu=성북구, dong=길음2동
# [법정→행정 매핑 실패] gu=성북구, dong=길음1동
# [법정→행정 매핑 실패] gu=성북구, dong=길음1동
# [법정→행정 매핑 실패] gu=성북구, dong=월곡1동
# [법정→행정 매핑 실패] gu=강북구, dong=번1동
# [법정→행정 매핑 실패] gu=강북구, dong=송중동
# [법정→행정 매핑 실패] gu=강북구, dong=수유3동
# [법정→행정 매핑 실패] gu=강북구, dong=번1동
# [법정→행정 매핑 실패] gu=도봉구, dong=쌍문2동
# [법정→행정 매핑 실패] gu=도봉구, dong=창2동
# [법정→행정 매핑 실패] gu=노원구, dong=월계3동
# [법정→행정 매핑 실패] gu=도봉구, dong=창1동
# [법정→행정 매핑 실패] gu=도봉구, dong=창2동
# [법정→행정 매핑 실패] gu=도봉구, dong=방학3동
# [법정→행정 매핑 실패] gu=노원구, dong=공릉2동
# [법정→행정 매핑 실패] gu=노원구, dong=중계2.3동
# [법정→행정 매핑 실패] gu=은평구, dong=신사1동
# [법정→행정 매핑 실패] gu=은평구, dong=갈현2동
# [법정→행정 매핑 실패] gu=은평구, dong=진관내동
# [법정→행정 매핑 실패] gu=은평구, dong=응암3동
# [법정→행정 매핑 실패] gu=은평구, dong=불광1동
# [법정→행정 매핑 실패] gu=서대문구, dong=홍제3동
# [법정→행정 매핑 실패] gu=None, dong=None
# [법정→행정 매핑 실패] gu=None, dong=None
# [법정→행정 매핑 실패] gu=마포구, dong=망원2동
# [법정→행정 매핑 실패] gu=마포구, dong=망원2동
# [법정→행정 매핑 실패] gu=양천구, dong=신월5동
# [법정→행정 매핑 실패] gu=양천구, dong=목5동
# [법정→행정 매핑 실패] gu=양천구, dong=신월5동
# [법정→행정 매핑 실패] gu=양천구, dong=목3동
# [법정→행정 매핑 실패] gu=양천구, dong=목5동
# [법정→행정 매핑 실패] gu=양천구, dong=신정7동
# [법정→행정 매핑 실패] gu=양천구, dong=목3동
# [법정→행정 매핑 실패] gu=양천구, dong=목4동
# [법정→행정 매핑 실패] gu=양천구, dong=신월2동
# [법정→행정 매핑 실패] gu=양천구, dong=신월1동
# [법정→행정 매핑 실패] gu=양천구, dong=목1동
# [법정→행정 매핑 실패] gu=양천구, dong=신정3동
# [법정→행정 매핑 실패] gu=강서구, dong=화곡3동
# [법정→행정 매핑 실패] gu=강서구, dong=등촌3동
# [법정→행정 매핑 실패] gu=강서구, dong=화곡3동
# [법정→행정 매핑 실패] gu=강서구, dong=화곡4동
# [법정→행정 매핑 실패] gu=강서구, dong=화곡1동
# [법정→행정 매핑 실패] gu=강서구, dong=방화1동
# [법정→행정 매핑 실패] gu=강서구, dong=화곡1동
# [법정→행정 매핑 실패] gu=강서구, dong=방화2동
# [법정→행정 매핑 실패] gu=강서구, dong=방화2동
# [법정→행정 매핑 실패] gu=구로구, dong=개봉1동
# [법정→행정 매핑 실패] gu=구로구, dong=구로1동
# [법정→행정 매핑 실패] gu=구로구, dong=오류2동
# [법정→행정 매핑 실패] gu=영등포구, dong=대림3동
# [법정→행정 매핑 실패] gu=영등포구, dong=대림1동
# [법정→행정 매핑 실패] gu=영등포구, dong=신길3동
# [법정→행정 매핑 실패] gu=동작구, dong=사당3동
# [법정→행정 매핑 실패] gu=동작구, dong=상도2동
# [법정→행정 매핑 실패] gu=관악구, dong=대학동
# [법정→행정 매핑 실패] gu=관악구, dong=중앙동
# [법정→행정 매핑 실패] gu=관악구, dong=은천동
# [법정→행정 매핑 실패] gu=관악구, dong=미성동
# [법정→행정 매핑 실패] gu=관악구, dong=서원동
# [법정→행정 매핑 실패] gu=관악구, dong=보라매동
# [법정→행정 매핑 실패] gu=None, dong=None
# [법정→행정 매핑 실패] gu=서초구, dong=방배본동
# [법정→행정 매핑 실패] gu=서초구, dong=서초2동
# [법정→행정 매핑 실패] gu=서초구, dong=방배1동
# [법정→행정 매핑 실패] gu=None, dong=None
# [법정→행정 매핑 실패] gu=강남구, dong=삼성1동
# [법정→행정 매핑 실패] gu=강남구, dong=압구정1동
# [법정→행정 매핑 실패] gu=강남구, dong=논현2동
# [법정→행정 매핑 실패] gu=강남구, dong=도곡2동
# [법정→행정 매핑 실패] gu=강남구, dong=삼성2동
# [법정→행정 매핑 실패] gu=강남구, dong=논현1동
# [법정→행정 매핑 실패] gu=송파구, dong=잠실4동
# [법정→행정 매핑 실패] gu=송파구, dong=송파1동
# [법정→행정 매핑 실패] gu=송파구, dong=가락2동
# [법정→행정 매핑 실패] gu=송파구, dong=잠실3동
# [법정→행정 매핑 실패] gu=송파구, dong=거여2동
# [법정→행정 매핑 실패] gu=송파구, dong=송파2동
# [법정→행정 매핑 실패] gu=강동구, dong=암사1동
# [법정→행정 매핑 실패] gu=강동구, dong=성내1동
# [법정→행정 매핑 실패] gu=강동구, dong=성내1동
# [법정→행정 매핑 실패] gu=강동구, dong=명일1동
# 저장 완료: C:\Users\Admin\Desktop\pick-your-place\data\processed\store__processed.csv
# ⚠️ 매핑 실패 데이터 저장 완료: C:\Users\Admin\Desktop\pick-your-place\data\processed\store__failed.csv
